# %% [markdown]
# # AI Agents: Build an Agent from Scratch (Part-2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Table of Contents
# 1. What is an Agent?
# 2. Implementation
# - 2.1 Pre-requisites
# - 2.2 Implementation Steps
# 3. Conclusion

# %% [markdown]
# how to build an agent from scratch using Python
# - quyết định dựa trên đầu vào
# - lựa chọn tool phù hợp
# - thực thi công cụ một cách chính xác

# %% [markdown]
# # 1. What is an Agent?

# %% [markdown]
# Các thành phần cốt lõi của một agent:
# - models
# - tools
# - toolbox
# - system prompt

# %% [markdown]
# # 2. Implementation

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## 2.1 Pre-requisites
# - python
# - virtual enviroment
# - install dependencis
# - setup ollama locally
# - pull a model (if required)

# %% [markdown]
# ## 2.2 Implementation Steps
# ![image.png](attachment:image.png)
#
# - Step 1: Setting Up the Environment
# - Step 2: Defining the Model Class
# - Step 3: Creating Tools for the Agent
# - Step 4: Building the Toolbox
# - Step 5: Creating the Agent Class
# - Step 6: Running the Agent

# %% [markdown]
# # 3. Conclusion

# %%
import requests
import json

url = "http://localhost:11434/api/generate"
headers = {"Content-Type": "application/json"}
data = {
    "model": "gemma3",
    "prompt": "Write a short poem about the sea.",
    "stream": False
}

try:
    response = requests.post(url, headers=headers, data=json.dumps(data))
    response.raise_for_status() # Raises an HTTPError for bad responses (4xx or 5xx)
    print(response.json())
except requests.exceptions.RequestException as e:
    print(f"Error making API request: {e}")
# Out:
# {'model': 'gemma3', 'created_at': '2025-07-29T08:52:42.9784785Z', 'response': "The ocean breathes, a restless sigh,\nOf turquoise depths and skies so high.\nWaves crash and roll, a silver sheen,\nA timeless, wild, and watery scene.\n\nSecrets held in coral bright,\nSunlight dances, warm and light.\nA boundless blue, a mystic grace,\nThe sea's embrace, a tranquil space.", 'done': True, 'done_reason': 'stop', 'context': [105, 2364, 107, 6974, 496, 2822, 27355, 1003, 506, 5442, 236761, 106, 107, 105, 4368, 107, 818, 12461, 186300, 236764, 496, 95480, 53647, 236764, 107, 4088, 54596, 43313, 532, 55748, 834, 1494, 236761, 107, 124959, 19592, 532, 6309, 236764, 496, 10173, 153323, 236764, 107, 236776, 56870, 236764, 6877, 236764, 532, 124743, 8317, 236761, 108, 159318, 4247, 528, 35809, 7804, 236764, 107, 18318, 3223, 64624, 236764, 6962, 532, 2214, 236761, 107, 236776, 140328, 3730, 236764, 496, 107709, 20499, 236764, 107, 818, 5442, 236789, 236751, 29887, 236764, 496, 61673, 2557, 236761], 'total_duration': 23658671500, 'load_duration': 7991253600, 'prompt_eval_count': 17, 'prompt_eval_duration': 6150412000, 'eval_count': 74, 'eval_duration': 9485098900}
